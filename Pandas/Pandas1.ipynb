# %% [markdown]
# # Pandas :
# explore data , manipulate data and get it ready for Data Analysis <br>
#
# <b>Why Pandas ?</b> <br>
# >Simple to use <br>
# > Integrated with many other data science & Ml python tools<br>
# > Helps you get data ready for machine learning<br>
#
#
# <b>What are we going to cover in this section :</b> <br>
# >Most useful functions<br>
# >Pandas Datatypes<br>
# >Importing & exporting data<br>
# >Describing data ## statically <br>
# >Viewing & selecting data<br>
# >Manipulating data<br>

# %%
import pandas as pd ##importing Pandas in jupyter notebook

# %%
# 2 main data Types
series = pd.Series(["BMW","HONDA","AUDI"]) ## here after pd.(Series "S" should be capital)

# %%
series ## series is a 1D <column>
# Out:
# 0      BMW
# 1    HONDA
# 2     AUDI
# dtype: object

# %%
colours = pd.Series(["RED","Yellow","BLUE"])
colours
# Out:
# 0       RED
# 1    Yellow
# 2      BLUE
# dtype: object

# %%
#DataFrame is 2 dimesional 
##More oftern used
## It takes a Python Dictionary
car_data = pd.DataFrame({"car make "  : series,"Colour":colours})
car_data
# Out:
#   car make   Colour
# 0       BMW     RED
# 1     HONDA  Yellow
# 2      AUDI    BLUE

# %%
## Import Data
car_sales = pd.read_csv ("car-sales.csv")
car_sales
#reading car-sales.csv to the variable car_sales
#csv = comma seperated values
#row is reffered to axis  = 0 
#column is referred to axis  =1
#the contents of this tables are called Data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting a DataFrame
car_sales.to_csv("exported-car-sales.csv")
#can also export it to excel by  .to_excel

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 36A3-5FA6
#
#  Directory of C:\Users\test\Desktop\ML_Sample_UdemyCourse\Pandas
#
# 11/20/2020  12:42 PM    <DIR>          .
# 11/20/2020  12:42 PM    <DIR>          ..
# 11/19/2020  11:32 PM    <DIR>          .ipynb_checkpoints
# 11/07/2020  04:16 PM           427,861 .jpg
# 11/03/2020  05:49 PM           332,025 6-step-ml-framework.png
# 11/19/2020  11:21 PM                56 car_colour.csv
# 11/04/2020  02:51 PM               369 car-sales.csv
# 11/18/2020  08:28 PM               392 car-sales-exported.csv
# 11/06/2020  07:09 PM               287 car-sales-missing-data.csv
# 11/04/2020  03:58 PM                 0 cd
# 11/19/2020  03:42 PM               348 debug.log
# 11/20/2020  12:54 PM               392 exported-car-sales.csv
# 11/20/2020  12:41 PM               371 exported-indexFalsed-car-sales.csv
# 11/20/2020  12:41 PM               392 exported-indexTrue-car-sales.csv
# 11/03/2020  05:49 PM            11,328 heart-disease.csv
# 11/05/2020  12:10 PM            19,590 JupyterWalkthrough1.ipynb
# 11/20/2020  12:42 PM           231,975 Pandas1.ipynb
# 11/07/2020  05:02 PM           341,236 pandas-anatomy-of-a-dataframe.png
# 11/19/2020  11:35 PM           106,061 pandas-exercises.ipynb
# 11/19/2020  11:35 PM           130,908 pandas-exercises-solutions.ipynb
#               17 File(s)      1,603,591 bytes
#                3 Dir(s)  867,619,069,952 bytes free

# %%
car_sales.to_csv("exported-indexFalsed-car-sales.csv",index = False)
car_sales.to_csv("exported-indexTrue-car-sales.csv",index = True)##adding an index column
# here we are telling python that no need to add an 
#extra column for indexing <by default index = False>

# %%
sales_car = pd.read_csv("exported-indexFalsed-car-sales.csv")
sales_car_True = pd.read_csv("exported-indexTrue-car-sales.csv")

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
sales_car_True
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Getting DataSet From GitHub Repository
# heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")<br>
# <b>Note: If you're using a link from GitHub, make sure it's in the "raw" format, by clicking the raw button.

# %% [markdown]
# # Describe Data

# %%
# Attribute - without parenthesis
# Atributes are just metaInfromation Stored about your Data
sales_car.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
sales_car.columns # columns name returned as a list
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
sales_car.index #information abour index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
sales_car.describe()
#This a function as this has parenthesis
#functions performs some task on data
#.describe fucntions returns some statistical information on Data<only on Integer Data Types> i. e it works only on numeric values
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
sales_car.info()
#info is kind of like index combined with dtypes attributes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
sales_car.mean()
# gives average of numerical columns<integer type>
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices  = pd.Series([23232,232334,232323,232323]) ## creating a Series Data Type Just to Demonstrate What mean function does
car_prices.mean()
# Out:
# 180053.0

# %%
sales_car.sum()
## combined all the columns
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
sales_car["Doors"].sum()
# running the sum function on a particular column
# Out:
# 40

# %%
len(sales_car) #returns the number of rows in your DataFrame
# Out:
# 10

# %% [markdown]
# # Viewing and Selecting Data

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
sales_car.tail()#last 5 rows of DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
sales_car.head() #top 5 rows of dataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
animals = pd.Series(["cat","pandas","dog","Snake"],index=[0,2,4,2]) ##defining a Series and custom Index

# %%
animals
# Out:
# 0       cat
# 2    pandas
# 4       dog
# 2     Snake
# dtype: object

# %%
animals.loc[2] ## loc refers to the index number specifies
# it reurns all the elements with the index specified
# Out:
# 2    pandas
# 2     Snake
# dtype: object

# %%
sales_car.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
animals
# Out:
# 0       cat
# 2    pandas
# 4       dog
# 2     Snake
# dtype: object

# %%
#.iloc
# iloc refers to position or you can say original index or
#starting from 0 it returns the 2nd positioned item
animals.iloc[2]
# Out:
# 'dog'

# %%
animals.iloc[:2]##this is called slicing
#i.e,we specify the starting index : and the ending index and python returns all the index betwween them
# : 2 means starting from 0 i.e, from the first (called 0 during indexing) row  return till the second <upto position 2>
# Out:
# 0       cat
# 2    pandas
# dtype: object

# %%
sales_car.loc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
sales_car["Colour"]
#sales_car.Colour both do the same task i.e, selecting the column
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
sales_car.Colour
## But if your column name has sapce it does not works you have to go with the[""] Syntax
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
#sales_car.Odometer (KM) ##returns ERROR

# %%
sales_car["Odometer (KM)"] ##works perfectly Fine
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
sales_car[sales_car["Make"]=="Toyota"] ##getting only specific data
#in the above code we are telling to the compiler that:
#show me only those rows which have Toyota under the Make Column
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
[sales_car["Odometer (KM)"]>100000]
##in the Boolean Format
# Out:
# [0     True
#  1    False
#  2    False
#  3    False
#  4     True
#  5    False
#  6    False
#  7    False
#  8    False
#  9    False
#  Name: Odometer (KM), dtype: bool]

# %%
sales_car[sales_car["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(sales_car["Make"],sales_car["Doors"])
#comparing two Columns
#kind of aggregates the two columns
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#Groupby
sales_car.groupby(["Make"]).mean()
#it groups the Data Frame on the Make column and gives the mean values of the all the Featues of the Data
# i.e, mean of the columns of Integer Data Types
#average
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
#Note :  the plot does not shows up, Run these codes before the plot fucntion and run the whole again
# %matplotlib inline
# import matplotlib.pyplot as plt
#this imports the library of plotting and inline function helps to show the plot in the Jupyter Notebook itself 

#Note plot only the NUMERIC Data Types

sales_car["Odometer (KM)"].plot()
#visualization of the Specific Column
# Out:
# <AxesSubplot:>

# %%
sales_car.plot()
#visualization of the entire DataFrame
# Out:
# <AxesSubplot:>

# %%
sales_car.hist()
# Histogram
# Out:
# array([[<AxesSubplot:title={'center':'Odometer (KM)'}>,
#         <AxesSubplot:title={'center':'Doors'}>]], dtype=object)

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#sales_car["Price"].plot()
#This does not runs since the Price is Object and Not numeric Data Type
# therefore we have to figure out a way to convert this

# %%
sales_car["Price"] = sales_car["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
##converted the Data Types of Object to INteger
# Did this by searching the Problem statement into Google
#Then matching The problem in StackOverflow
#Copies the code , Tweaked it according to my Code Requirements/Prerequisites



#ALternative way:
#car_sales["Price"]=car_sales['Price'].str.replace(',', '').str.replace('$', '').astype(float)



#What this does is that it (.str.replace) replaces the $ sign with a " " space and replaces the type with an integer
#Note ; There are solutions that only replace the dollar sign and add extra zeros 
#Look for the proper solutions

# %%
sales_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int32
# dtypes: int32(1), int64(2), object(2)
# memory usage: 488.0+ bytes

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %% [markdown]
# # Manipulating Data

# %%
sales_car["Make"].str.lower() #lowercases
#here with the .str we are accesssing the string value of the column
#.lower() helps to lowercases alll the string accessed here
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
sales_car
#as we can see the loweered string has not been saved to the original data
#to save to the original data  we have to reassign the lowered to the original DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
sales_car["Make"] = sales_car["Make"].str.lower()
#here we reassign the original Make column to the lowered column

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
#in real world we also get missing data 
# to fix ot we have :

# %%
sales_car_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
sales_car_missing
#here the NaN are the missing values
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
sales_car_missing["Odometer"]=sales_car_missing["Odometer"].fillna(sales_car_missing["Odometer"].mean())

# we can also use This line inplace = True will assign this to out DataFrame there itself
#sales_car_missing["Odometer"].fillna(sales_car_missing["Odometer"].mean(),inplace = True)

#what this does is that it takes all the missing values(NaN) and fills it with the mean vale of the Odometer
#At the same time we are assigning it to the original value as well

# %%
sales_car_missing.dropna()
#it drops the rows if one of the values in the rows is NaN
#by default INplace is Flase so this changes are not saved inthe original DataFrame
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
#creat data from existing data
# columns from series
seats_column = pd.Series([5,5,5,5,5])

#new column called seats
sales_car["Seats"] = seats_column
sales_car
#we created a new column called seats
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
sales_car["Seats"].fillna(5,inplace = True)
#filling in missing NaN values with 5

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
#columns from python List
fuel_economy = [7,9,5,7,3,2,3,2,5,6]
sales_car["Fuel per 100 KM"] = fuel_economy
# here if you give less values (10 as of this data set ) we will get an error
#****In python list, pandas does not add missing values****

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6

# %%
#creating column from another column
sales_car["Total fuel Used (Litres)"] = sales_car["Odometer (KM)"]/100 * sales_car["Fuel per 100 KM"]
sales_car
# created a new column named Total fuel used 
# total fuel used = distance travelled by car("Odometer")/100 * fuel per 100 km
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6
#
#    Total fuel Used (Litres)
# 0                  10503.01
# 1                   7910.91
# 2                   1627.45
# 3                    782.53
# 4                   6392.85
# 5                   1984.26
# 6                   1370.94
# 7                   1094.76
# 8                   3000.00
# 9                   1896.00

# %%
#create a column from a single value
sales_car["Number of Wheels"] = 4
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6
#
#    Total fuel Used (Litres)  Number of Wheels
# 0                  10503.01                 4
# 1                   7910.91                 4
# 2                   1627.45                 4
# 3                    782.53                 4
# 4                   6392.85                 4
# 5                   1984.26                 4
# 6                   1370.94                 4
# 7                   1094.76                 4
# 8                   3000.00                 4
# 9                   1896.00                 4

# %%
sales_car["Passed road safety"] = True
sales_car.dtypes
#bool  = Boolean
#pandas is versatile you can use variety of data tupes
# Out:
# Make                         object
# Colour                       object
# Odometer (KM)                 int64
# Doors                         int64
# Price                         int32
# Seats                       float64
# Fuel per 100 KM               int64
# Total fuel Used (Litres)    float64
# Number of Wheels              int64
# Passed road safety             bool
# dtype: object

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6
#
#    Total fuel Used (Litres)  Number of Wheels  Passed road safety
# 0                  10503.01                 4                True
# 1                   7910.91                 4                True
# 2                   1627.45                 4                True
# 3                    782.53                 4                True
# 4                   6392.85                 4                True
# 5                   1984.26                 4                True
# 6                   1370.94                 4                True
# 7                   1094.76                 4                True
# 8                   3000.00                 4                True
# 9                   1896.00                 4                True

# %%
#removing one of the columns
sales_car.drop("Total fuel Used (Litres)",axis = 1,inplace = True)
sales_car
#here axis = 1 means column and axis 0 means rows
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
#shuffling rows in a database
shuffled_sales_car = sales_car.sample(frac=1)
#frac = what part of the data you want to randomize(randomizing reffers to shuffling here)
# eg : 0.5 for 50% of the data 1 for 100% of data and same like that

# %%
shuffled_sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 9  nissan  White          31600      4   9700    5.0                6
# 6   honda   Blue          45698      4   7500    5.0                3
# 8  toyota  White          60000      4   6250    5.0                5
# 5  toyota  Green          99213      4   4500    5.0                2
# 3     bmw  Black          11179      5  22000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 4  nissan  White         213095      4   3500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 9                 4                True
# 6                 4                True
# 8                 4                True
# 5                 4                True
# 3                 4                True
# 1                 4                True
# 2                 4                True
# 4                 4                True
# 7                 4                True

# %%
#only selecting 20%
#since in real world there are millions of rows 
shuffled_sales_car.sample(frac = 0.2)
# Out:
#     Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 1  honda    Red          87899      4   5000    5.0                9
# 3    bmw  Black          11179      5  22000    5.0                7
#
#    Number of Wheels  Passed road safety
# 1                 4                True
# 3                 4                True

# %%
#reseting the shuffled to order wise index numbers
shuffled_sales_car.reset_index(drop = True,inplace = True)
#drop is false by default and if it is false it does not resets , 
# it creates a new index column starting from zero
#then you would have 2 index column, one from your shuffled data set and one which is being created here

# %%
shuffled_sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1  nissan  White          31600      4   9700    5.0                6
# 2   honda   Blue          45698      4   7500    5.0                3
# 3  toyota  White          60000      4   6250    5.0                5
# 4  toyota  Green          99213      4   4500    5.0                2
# 5     bmw  Black          11179      5  22000    5.0                7
# 6   honda    Red          87899      4   5000    5.0                9
# 7  toyota   Blue          32549      3   7000    5.0                5
# 8  nissan  White         213095      4   3500    5.0                3
# 9   honda   Blue          54738      4   7000    5.0                2
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000    5.0                7
# 1   honda    Red          87899      4   5000    5.0                9
# 2  toyota   Blue          32549      3   7000    5.0                5
# 3     bmw  Black          11179      5  22000    5.0                7
# 4  nissan  White         213095      4   3500    5.0                3
# 5  toyota  Green          99213      4   4500    5.0                2
# 6   honda   Blue          45698      4   7500    5.0                3
# 7   honda   Blue          54738      4   7000    5.0                2
# 8  toyota  White          60000      4   6250    5.0                5
# 9  nissan  White          31600      4   9700    5.0                6
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
sales_car["Odometer (KM)"] = sales_car["Odometer (KM)"].apply(lambda x : x/1.6)
#lambda is a fucntion in python
#here lambda function takes the x("Odometer values") and divides it by 1.6 and returns the divided number
#here we are converting KM to Miles
#apply is a way where we can assign a function to a column
sales_car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White      93776.875      4   4000    5.0                7
# 1   honda    Red      54936.875      4   5000    5.0                9
# 2  toyota   Blue      20343.125      3   7000    5.0                5
# 3     bmw  Black       6986.875      5  22000    5.0                7
# 4  nissan  White     133184.375      4   3500    5.0                3
# 5  toyota  Green      62008.125      4   4500    5.0                2
# 6   honda   Blue      28561.250      4   7500    5.0                3
# 7   honda   Blue      34211.250      4   7000    5.0                2
# 8  toyota  White      37500.000      4   6250    5.0                5
# 9  nissan  White      19750.000      4   9700    5.0                6
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True

# %%
#renaming a column
sales_car = sales_car.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
sales_car
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         93776.875      4   4000    5.0                7
# 1   honda    Red         54936.875      4   5000    5.0                9
# 2  toyota   Blue         20343.125      3   7000    5.0                5
# 3     bmw  Black          6986.875      5  22000    5.0                7
# 4  nissan  White        133184.375      4   3500    5.0                3
# 5  toyota  Green         62008.125      4   4500    5.0                2
# 6   honda   Blue         28561.250      4   7500    5.0                3
# 7   honda   Blue         34211.250      4   7000    5.0                2
# 8  toyota  White         37500.000      4   6250    5.0                5
# 9  nissan  White         19750.000      4   9700    5.0                6
#
#    Number of Wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# 3                 4                True
# 4                 4                True
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 8                 4                True
# 9                 4                True
